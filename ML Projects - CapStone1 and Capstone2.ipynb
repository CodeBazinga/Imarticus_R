# %% [markdown]
# #### CapStone1 - ML
#
# #### Add-ons
# a) Add-On-I
# 1) Web Scraping<br>
# 2) API-Fetching - openweatherapi <br>
#
# b) Add-On-II
# 1) Tableau(Dashboards, Stories)<br>
# 2) Power BI(Reports)<br>
#
# c) Add-On-III
# 1) Model Wep App (Flask or Streamlit)<br>
# 2) Model deploymemnt (Heroku, Digital Ocean, AWS, Azure etc)<br>
# 3) ML API - Fast API<br>
# 4) Mobile App<br>
#
# #### ML Capstone
# 1) Recommendation System <br>
# * a) (Movie, Web Series,(Netflix,Amazon Prime) Books(Smashwords), Songs(Spotify,Gaana))
# * b) Content Based, Collaborative Recom System
# * c) Approaches - Cosine similarity, SVD etc
#
# 2) Customer Churn <br>
# * a) Approachh - RFM Model (Recency, Freqency, Monetory) + Clustering (KMeans, DBSCAN, Agglomerative etc)
#
# 3) Market Basket Analsyis<br>
# * a) Approaches - Apriori, Eclat
# * b) Concepts - Lift, Support, Confidence
#
# 4) NLP (Text Classification)
# * b) Sentiment Analysis Reviews (Scraped from Flipkart, Amazon) MultinomailNB, Spacy, TextBlob
#
# 5) Case Studies - Startup/Disaster/Election/Stock/Quora/<br>
# * a) Zomato<br>
# * b) Uber data - Demand Supply Analysis<br>
# * c) Delhivery<br>
# * d) FedEx<br>
# * e) data.gov<br>
# * f) Zerodha, Upstox, SmallCase
#
# 6) ML Projects(Regression/Classification)<br>
# * a) Comparison of different models<br>
# * b) Web App using Streamlit(considering model comparison) using widgets<br>
# * c) Combination (Clustering + Classification)<br>
#
# 7) Cricket Match Analysis, Football Analysis, Stock Portfolio Analysis, Crypto<br>
#
# 8) OpenCV<br>
# * Object Counting, Haarcascade etc<br>
# * Shape detection,shape counting<br>
#
# 9) Job Scrape - Indeed, Naukri<br>
# * Users Scrape - LinkedIn
# * User profile(Resume) - keyword Search - Data Science
# * Match job with corresponding user profile
#
# 10) Automation - Selenium<br>

# %% [markdown]
# #### CapStone2
#
# 1) NLP
# * a) Stock/crypto Price prediction using LSTM/GRU
# * b) Text clustering - LDA
# * c) Image Caption generstor
# * d) Song lyrics completion
# * e) Autocrrect
#
# 2) Chatbot<br>
# * a) Basic Chatbot - LSTM
# * b) RASA, DialogFlow
#
# 3) Image, OpenCV
# * a) CNN, Transfer Learning Based Project
# * b) Image Segmentation: Approaches - Mask RCNN, Fast RCNN, Faster RCNN
# * c) YOLO
#
# 4) Audio <br>
# a) Audio Classification - Librosa
